# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
tf.__version__
# Out:
# '2.18.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %%
batch_size = 8
img_height = 300
img_width = 300
image_size = (img_height, img_width)

# %% [markdown]
# ### Processando o TrainSet

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'dataset/',
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=image_size,
    batch_size=batch_size,)
# Out:
# Found 2615 files belonging to 3 classes.
# Using 2092 files for training.

# %% [markdown]
# ### Processando o TestSet

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'dataset/',
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=image_size,
    batch_size=batch_size,)
# Out:
# Found 2615 files belonging to 3 classes.
# Using 2092 files for training.

# %% [markdown]
# #### Primeiras 9 imagens

# %%
class_names = training_set.class_names
print(class_names)
# Out:
# ['Cercosporiose', 'Ferrugem', 'Saudavel']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in training_set.take(1):
  for i in range(8):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## Configurando o conjunto de dados

# %%
AUTOTUNE = tf.data.AUTOTUNE

training_set = training_set.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_set = validation_set.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Padronizando os dados

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = training_set.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

# Agora os valores dos pixels estão entre 0 e 1
print(np.min(first_image), np.max(first_image))
# Out:
# 0.020171242 0.9998719

# %% [markdown]
# ## Construíndo a CNN

# %% [markdown]
# ### Iniciando o modelo

# %%
num_classes = len(class_names)

cnn = Sequential(
    [
        layers.Rescaling(1./255, 
                         input_shape=(img_height, 
                                      img_width, 
                                      3)),
        layers.RandomFlip("horizontal",
                          input_shape=(img_height,
                                       img_width,
                                       3)),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        
        layers.Conv2D(16, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(256, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(512, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes)
    ]
)

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Sumario do modelo

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_4 (Rescaling)              │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_flip_1 (RandomFlip)           │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_rotation_1 (RandomRotation)   │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_zoom_1 (RandomZoom)           │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 300, 300, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 150, 150, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 150, 150, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 75, 75, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 75, 75, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 37, 37, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 37, 37, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 18, 18, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 18, 18, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 9, 9, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 9, 9, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       1,048,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,621,859 (10.00 MB)
#  Trainable params: 2,621,859 (10.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Treinando a CNN

# %%
epochs = 20

history = cnn.fit(
    training_set, 
    validation_data = validation_set, 
    epochs = epochs)
# Out:
# Epoch 1/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 86s 313ms/step - accuracy: 0.4189 - loss: 1.0537 - val_accuracy: 0.4402 - val_loss: 1.0271
# Epoch 2/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 76s 289ms/step - accuracy: 0.5139 - loss: 0.9221 - val_accuracy: 0.8059 - val_loss: 0.3416
# Epoch 3/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 77s 295ms/step - accuracy: 0.7889 - loss: 0.4703 - val_accuracy: 0.8303 - val_loss: 0.2866
# Epoch 4/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 77s 293ms/step - accuracy: 0.8173 - loss: 0.3665 - val_accuracy: 0.8446 - val_loss: 0.2862
# Epoch 5/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 76s 289ms/step - accuracy: 0.8243 - loss: 0.3391 - val_accuracy: 0.8924 - val_loss: 0.2417
# Epoch 6/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 78s 299ms/step - accuracy: 0.8439 - loss: 0.2983 - val_accuracy: 0.8504 - val_loss: 0.3350
# Epoch 7/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 80s 305ms/step - accuracy: 0.8630 - loss: 0.3176 - val_accuracy: 0.8934 - val_loss: 0.2493
# Epoch 8/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 83s 318ms/step - accuracy: 0.8722 - loss: 0.2963 - val_accuracy: 0.9101 - val_loss: 0.2018
# Epoch 9/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 81s 310ms/step - accuracy: 0.9022 - loss: 0.2633 - val_accuracy: 0.9173 - val_loss: 0.2131
# Epoch 10/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 71s 270ms/step - accuracy: 0.8833 - loss: 0.2936 - val_accuracy: 0.9259 - val_loss: 0.1927
# Epoch 11/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 67s 256ms/step - accuracy: 0.8997 - loss: 0.2431 - val_accuracy: 0.9273 - val_loss: 0.1755
# Epoch 12/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 68s 260ms/step - accuracy: 0.9110 - loss: 0.2283 - val_accuracy: 0.8834 - val_loss: 0.2439
# Epoch 13/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 70s 266ms/step - accuracy: 0.9135 - loss: 0.2323 - val_accuracy: 0.8920 - val_loss: 0.2490
# Epoch 14/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 70s 267ms/step - accuracy: 0.9096 - loss: 0.2244 - val_accuracy: 0.8437 - val_loss: 0.3380
# Epoch 15/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 69s 264ms/step - accuracy: 0.9197 - loss: 0.2199 - val_accuracy: 0.9178 - val_loss: 0.1927
# Epoch 16/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 68s 261ms/step - accuracy: 0.9060 - loss: 0.2324 - val_accuracy: 0.9316 - val_loss: 0.1720
# Epoch 17/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 69s 265ms/step - accuracy: 0.9154 - loss: 0.2042 - val_accuracy: 0.9211 - val_loss: 0.1877
# Epoch 18/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 73s 279ms/step - accuracy: 0.9274 - loss: 0.1925 - val_accuracy: 0.9441 - val_loss: 0.1537
# Epoch 19/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 75s 288ms/step - accuracy: 0.9297 - loss: 0.1945 - val_accuracy: 0.9034 - val_loss: 0.2794
# Epoch 20/20
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 72s 275ms/step - accuracy: 0.9235 - loss: 0.1908 - val_accuracy: 0.9364 - val_loss: 0.1659

# %% [markdown]
# ### Visualizando os dados do treinamento

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Precisão do Treinamento")
plt.plot(epochs_range, val_acc, label="Precisão da Validação")
plt.legend(loc='lower right')
plt.title('Precisão do treinamento e da validação')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Precisão do Treinamento")
plt.plot(epochs_range, val_loss, label="Precisão da Validação")
plt.legend(loc='lower right')
plt.title('Perda no treinamento e na validação')

plt.show()

# %% [markdown]
# ## Fazendo apenas uma predição

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('./testset/Cercosporiose/cercosporiose15.jpg', target_size = image_size)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)

print(class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ['Cercosporiose', 'Ferrugem', 'Saudavel']

# %%
print(result)
# Out:
# [[  4.3769207    0.13541324 -21.533245  ]]

# %% [markdown]
# ### Salvando o modelo

# %%
cnn.save("SicknessMinder_V3_4_1.keras")

# %% [markdown]
# ### Abrindo o modelo

# %%
cnn_V2_1 = load_model("SicknessMinder_V2_1.keras")
loss, accuracy = cnn_V2_1.evaluate(test_set)
print(f'Loss: {loss}, Accuracy: {accuracy}')
